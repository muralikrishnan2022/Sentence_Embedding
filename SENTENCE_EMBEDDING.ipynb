# %% [markdown]
# <a href="https://colab.research.google.com/github/muralikrishnan2022/Sentence_Embedding/blob/main/SENTENCE_EMBEDDING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install nltk

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer()
data_corpus = ["Hi this is M.Murali krishnan here. My register number is 22MIS1177 "]
vocabulary = vectorizer.fit(data_corpus)
X= vectorizer.transform(data_corpus)
print(X.toarray())
# Out:
# [[1 1 1 2 1 1 1 1 1 1]]

# %%
from nltk.corpus import abc

# %%
from gensim.models import Word2Vec
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
 ['this', 'is', 'the', 'second', 'sentence'],
 ['yet', 'another', 'sentence'],
 ['one', 'more', 'sentence'],
 ['and', 'the', 'final', 'sentence']]

# %%
# train model
model = Word2Vec(sentences, min_count=1)
print(model)
# Out:
# Word2Vec<vocab=14, vector_size=100, alpha=0.025>

# %%
model.save('model.bin')
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# Word2Vec<vocab=14, vector_size=100, alpha=0.025>

# %%
model.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# Word2Vec<vocab=14, vector_size=100, alpha=0.025>

# %%
words = list(new_model.wv.index_to_key)
vocab_len = len(new_model.wv)
print(vocab_len)
print(words)
# Out:
# 14
# ['sentence', 'the', 'is', 'this', 'final', 'and', 'more', 'one', 'another', 'yet', 'second', 'word2vec', 'for', 'first']

# %%
print(new_model.wv['the'])
# Out:
# [-8.6196875e-03  3.6657380e-03  5.1898835e-03  5.7419385e-03
#   7.4669183e-03 -6.1676754e-03  1.1056137e-03  6.0472824e-03
#  -2.8400505e-03 -6.1735227e-03 -4.1022300e-04 -8.3689485e-03
#  -5.6000124e-03  7.1045388e-03  3.3525396e-03  7.2256695e-03
#   6.8002474e-03  7.5307419e-03 -3.7891543e-03 -5.6180597e-04
#   2.3483764e-03 -4.5190323e-03  8.3887316e-03 -9.8581640e-03
#   6.7646410e-03  2.9144168e-03 -4.9328315e-03  4.3981876e-03
#  -1.7395747e-03  6.7113843e-03  9.9648498e-03 -4.3624435e-03
#  -5.9933780e-04 -5.6956373e-03  3.8508223e-03  2.7866268e-03
#   6.8910765e-03  6.1010956e-03  9.5384968e-03  9.2734173e-03
#   7.8980681e-03 -6.9895042e-03 -9.1558648e-03 -3.5575271e-04
#  -3.0998408e-03  7.8943167e-03  5.9385742e-03 -1.5456629e-03
#   1.5109634e-03  1.7900408e-03  7.8175711e-03 -9.5101865e-03
#  -2.0553112e-04  3.4691966e-03 -9.3897223e-04  8.3817719e-03
#   9.0107834e-03  6.5365066e-03 -7.1162102e-04  7.7104042e-03
# ...

# %%
for word in words:
  print(new_model.wv[word])
# Out:
# [-5.3622725e-04  2.3643136e-04  5.1033497e-03  9.0092728e-03
#  -9.3029495e-03 -7.1168090e-03  6.4588725e-03  8.9729885e-03
#  -5.0154282e-03 -3.7633716e-03  7.3805046e-03 -1.5334714e-03
#  -4.5366134e-03  6.5540518e-03 -4.8601604e-03 -1.8160177e-03
#   2.8765798e-03  9.9187379e-04 -8.2852151e-03 -9.4488179e-03
#   7.3117660e-03  5.0702621e-03  6.7576934e-03  7.6286553e-04
#   6.3508903e-03 -3.4053659e-03 -9.4640139e-04  5.7685734e-03
#  -7.5216377e-03 -3.9361035e-03 -7.5115822e-03 -9.3004224e-04
#   9.5381187e-03 -7.3191668e-03 -2.3337686e-03 -1.9377411e-03
#   8.0774371e-03 -5.9308959e-03  4.5162440e-05 -4.7537340e-03
#  -9.6035507e-03  5.0072931e-03 -8.7595852e-03 -4.3918253e-03
#  -3.5099984e-05 -2.9618145e-04 -7.6612402e-03  9.6147433e-03
#   4.9820580e-03  9.2331432e-03 -8.1579173e-03  4.4957981e-03
#  -4.1370760e-03  8.2453608e-04  8.4986202e-03 -4.4621765e-03
#   4.5175003e-03 -6.7869602e-03 -3.5484887e-03  9.3985079e-03
# ...
